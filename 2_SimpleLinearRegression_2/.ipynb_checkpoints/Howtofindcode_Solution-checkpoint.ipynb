# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading raw data

# %%
#How to read data from anywhere on your drive
raw_data = pd.read_csv(r'C:\Users\alexa\E7_PC-Shop.csv')
raw_data.head()
# Out:
#        Brand  Sales  ShopTime
# 0      Apple    6.0     123.0
# 1      Apple    6.0     708.0
# 2  Microsoft    8.0     456.0
# 3        IBM    8.0     324.0
# 4      Apple   10.0     672.0

# %%
raw_data
# Out:
#           Brand  Sales  ShopTime
# 0         Apple    6.0     123.0
# 1         Apple    6.0     708.0
# 2     Microsoft    8.0     456.0
# 3           IBM    8.0     324.0
# 4         Apple   10.0     672.0
# ...         ...    ...       ...
# 3705  Microsoft  399.0    3264.0
# 3706        IBM  399.0    4068.0
# 3707        IBM  399.0    3288.0
# 3708      Apple  399.0    3588.0
# 3709        IBM  399.0    3840.0
#
# [3710 rows x 3 columns]

# %% [markdown]
# ## Explore descriptive statistics

# %%
raw_data.describe(include='all')
# Out:
#         Brand        Sales     ShopTime
# count    3710  3710.000000  3710.000000
# unique      3          NaN          NaN
# top     Apple          NaN          NaN
# freq     1352          NaN          NaN
# mean      NaN   128.818329  1864.553908
# std       NaN    88.737688   836.230723
# min       NaN     6.000000   121.000000
# 25%       NaN    66.000000  1236.000000
# 50%       NaN   104.000000  1920.000000
# 75%       NaN   175.000000  2460.000000
# max       NaN   399.000000  4080.000000

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Define the dependent and the independent variables

# %%
y = raw_data ['Sales']
x1 = raw_data ['ShopTime']

# %% [markdown]
# ## Explore the data

# %%
plt.scatter(x1,y)
plt.xlabel('ShopTime', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.show()

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                 2.239e+04
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):               0.00
# Time:                        16:48:47   Log-Likelihood:                -18286.
# No. Observations:                3710   AIC:                         3.658e+04
# Df Residuals:                    3708   BIC:                         3.659e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -54.4467      1.342    -40.563      0.000     -57.078     -51.815
# ...

# %%
plt.scatter(x1,y)
yhat = 0.0983*x1 - 54.4467
fig = plt.plot(x1,yhat, lw=4, c='orange', label ='regression line')
plt.xlabel('ShopTime', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.show()

# %% [markdown]
# ## Additional Lecture: Preparing Data Sets per Brand

# %%
raw_data.describe(include='all')
# Out:
#         Brand        Sales     ShopTime
# count    3710  3710.000000  3710.000000
# unique      3          NaN          NaN
# top     Apple          NaN          NaN
# freq     1352          NaN          NaN
# mean      NaN   128.818329  1864.553908
# std       NaN    88.737688   836.230723
# min       NaN     6.000000   121.000000
# 25%       NaN    66.000000  1236.000000
# 50%       NaN   104.000000  1920.000000
# 75%       NaN   175.000000  2460.000000
# max       NaN   399.000000  4080.000000

# %%
raw_data
# Out:
#           Brand  Sales  ShopTime
# 0         Apple    6.0     123.0
# 1         Apple    6.0     708.0
# 2     Microsoft    8.0     456.0
# 3           IBM    8.0     324.0
# 4         Apple   10.0     672.0
# ...         ...    ...       ...
# 3705  Microsoft  399.0    3264.0
# 3706        IBM  399.0    4068.0
# 3707        IBM  399.0    3288.0
# 3708      Apple  399.0    3588.0
# 3709        IBM  399.0    3840.0
#
# [3710 rows x 3 columns]

# %%
#Find link to the description of the function below
def filter_rows_by_values(df, col, values):
    return df[~df[col].isin(values)]

data_ibm = filter_rows_by_values(raw_data, "Brand", ["Apple","Microsoft"])
data_apple = filter_rows_by_values(raw_data, "Brand", ["IBM","Microsoft"])
data_microsoft = filter_rows_by_values(raw_data, "Brand", ["Apple","IBM"])

# %%
data_ibm
# Out:
#      Brand  Sales  ShopTime
# 3      IBM    8.0     324.0
# 7      IBM   12.0     300.0
# 8      IBM   12.0     408.0
# 16     IBM   14.0     564.0
# 19     IBM   14.0     348.0
# ...    ...    ...       ...
# 3696   IBM  396.0    3336.0
# 3700   IBM  399.0    3840.0
# 3706   IBM  399.0    4068.0
# 3707   IBM  399.0    3288.0
# 3709   IBM  399.0    3840.0
#
# [1244 rows x 3 columns]

# %%
data_microsoft
# Out:
#           Brand  Sales  ShopTime
# 2     Microsoft    8.0     456.0
# 9     Microsoft   12.0     420.0
# 10    Microsoft   12.0     286.0
# 11    Microsoft   13.0     420.0
# 14    Microsoft   14.0     348.0
# ...         ...    ...       ...
# 3699  Microsoft  399.0    3756.0
# 3701  Microsoft  399.0    3960.0
# 3702  Microsoft  399.0    3288.0
# 3703  Microsoft  399.0    3360.0
# 3705  Microsoft  399.0    3264.0
#
# [1114 rows x 3 columns]

# %%
data_ibm
# Out:
#      Brand  Sales  ShopTime
# 3      IBM    8.0     324.0
# 7      IBM   12.0     300.0
# 8      IBM   12.0     408.0
# 16     IBM   14.0     564.0
# 19     IBM   14.0     348.0
# ...    ...    ...       ...
# 3696   IBM  396.0    3336.0
# 3700   IBM  399.0    3840.0
# 3706   IBM  399.0    4068.0
# 3707   IBM  399.0    3288.0
# 3709   IBM  399.0    3840.0
#
# [1244 rows x 3 columns]

# %% [markdown]
# ## Run Regressions per Sub-Data File

# %%
y = data_ibm ['Sales']
x1 = data_ibm ['ShopTime']
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     7313.
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):               0.00
# Time:                        16:48:48   Log-Likelihood:                -6138.5
# No. Observations:                1244   AIC:                         1.228e+04
# Df Residuals:                    1242   BIC:                         1.229e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -53.1259      2.353    -22.575      0.000     -57.743     -48.509
# ...

# %%
y = data_apple ['Sales']
x1 = data_apple ['ShopTime']
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     8031.
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):               0.00
# Time:                        16:48:48   Log-Likelihood:                -6650.9
# No. Observations:                1352   AIC:                         1.331e+04
# Df Residuals:                    1350   BIC:                         1.332e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -53.6135      2.202    -24.342      0.000     -57.934     -49.293
# ...

# %%
y = data_microsoft ['Sales']
x1 = data_microsoft ['ShopTime']
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     7043.
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):               0.00
# Time:                        16:48:48   Log-Likelihood:                -5493.8
# No. Observations:                1114   AIC:                         1.099e+04
# Df Residuals:                    1112   BIC:                         1.100e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -56.8726      2.437    -23.336      0.000     -61.654     -52.091
# ...

# %%
data_ibm.describe()
# Out:
#              Sales     ShopTime
# count  1244.000000  1244.000000
# mean    130.827974  1890.670418
# std      88.312267   839.199406
# min       8.000000   122.000000
# 25%      69.000000  1284.000000
# 50%     105.500000  1956.000000
# 75%     178.000000  2489.250000
# max     399.000000  4080.000000

# %%
data_apple.describe()
# Out:
#              Sales     ShopTime
# count  1352.000000  1352.000000
# mean    126.464497  1843.920118
# std      87.356931   827.633709
# min       6.000000   121.000000
# 25%      67.000000  1233.000000
# 50%     100.000000  1884.000000
# 75%     170.000000  2412.000000
# max     399.000000  3996.000000

# %%
data_microsoft.describe()
# Out:
#              Sales     ShopTime
# count  1114.000000  1114.000000
# mean    129.430880  1860.431777
# std      90.863429   843.237881
# min       8.000000   122.000000
# 25%      63.000000  1200.000000
# 50%     103.500000  1920.000000
# 75%     175.000000  2469.000000
# max     399.000000  4044.000000

# %% [markdown]
# Find description on https://stackoverflow.com/questions/18172851/deleting-dataframe-row-in-pandas-based-on-column-value
